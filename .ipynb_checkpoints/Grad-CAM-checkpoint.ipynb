# %%
from numpy import random
import warnings
warnings.filterwarnings('ignore')
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
dataset = pd.read_csv('finaldataset.csv')
dataset
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     -0.263502 -0.167903 -0.446342 -0.005728  0.039776  0.011514  0.037622
# 1     -0.538172  0.767607  0.328654 -0.473975  0.148248 -0.063536  0.449899
# 2     -0.598868  0.871351  0.480035 -0.522922  0.243959  0.172053  0.179860
# 3     -0.269532 -0.167819 -0.446780 -0.003435  0.051544  0.005336  0.032856
# 4      1.301458  1.493234  0.443243 -0.585408  0.526601  0.436103  0.073433
# ...         ...       ...       ...       ...       ...       ...       ...
# 59995  2.077835  0.528904 -0.638154 -0.162049  0.005191  0.733870  0.000879
# 59996 -0.267291 -0.167952 -0.447170 -0.004093  0.047140  0.008548  0.035052
# 59997  0.084310 -0.727216  0.303984 -0.043225 -0.343127  0.157525  0.042986
# 59998 -0.249318 -0.168080 -0.445541 -0.010482  0.009916  0.028458  0.048470
# 59999  1.434417  1.120843 -0.109867 -0.116235 -0.689623 -0.162512 -0.018161
#
#             PC8       PC9      PC10  ...      PC42      PC43      PC44  \
# 0     -0.041895 -0.041791  0.072465  ...  0.000063 -0.000136  0.000141
# 1     -0.005152 -0.011905 -0.200623  ...  0.000016  0.000295 -0.001125
# 2     -0.021183 -0.054757 -0.028758  ...  0.000576 -0.000865  0.003551
# 3     -0.031816 -0.043031  0.066463  ...  0.000061 -0.000086  0.000459
# 4      0.140542 -0.157768  0.095442  ... -0.002067  0.002237  0.002377
# ...         ...       ...       ...  ...       ...       ...       ...
# 59995 -0.048069  0.634075 -0.203996  ...  0.002381  0.000581  0.000115
# 59996 -0.036177 -0.042960  0.070113  ...  0.000014 -0.000077  0.000515
# 59997 -0.117888 -0.077339 -0.113971  ... -0.003512  0.005160  0.001533
# 59998 -0.068136 -0.038032  0.088134  ... -0.000114 -0.000197 -0.000635
# 59999  0.014700 -0.209282  0.038659  ... -0.000290  0.001007 -0.001133
#
#            PC45      PC46          PC47      PC48      PC49      PC50  Label
# 0     -0.000093  0.000126 -3.975933e-06  0.000629 -0.000012 -0.000010      0
# 1      0.000740  0.000209 -5.568686e-07  0.000184 -0.000019 -0.000048      0
# 2     -0.002204 -0.000963 -1.324140e-05  0.000099  0.000035  0.000003      0
# 3     -0.000174 -0.000378  1.344395e-05  0.000765 -0.000027  0.000013      0
# 4     -0.000196 -0.003152  2.844513e-05 -0.000816 -0.000008  0.000609      0
# ...         ...       ...           ...       ...       ...       ...    ...
# 59995  0.001120 -0.003417  2.356347e-06  0.002237 -0.000023 -0.000235      1
# 59996 -0.000204 -0.000874  1.033951e-05  0.001310 -0.000026  0.000012      0
# 59997  0.000776  0.004196 -2.853988e-05 -0.001357  0.000005  0.000051      0
# 59998  0.000170  0.000311 -4.528510e-05  0.001228 -0.000025 -0.000066      0
# 59999  0.002160 -0.000417 -7.810193e-06 -0.002101  0.000013  0.000083      1
#
# [60000 rows x 51 columns]

# %%
X = dataset.drop('Label', axis=1)    
Y = dataset['Label']

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Label encoding for categorical data (if needed)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(Y)

#Y = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
Xtrain = np.array(X_train)
Xtrain = np.reshape(Xtrain, (Xtrain.shape[0], Xtrain.shape[1], 1))
Xtest = np.array(X_test)
Xtest = np.reshape(Xtest, (Xtest.shape[0], Xtest.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, LearningRateScheduler
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
# Define early stopping and learning rate scheduler callbacks
initial_learning_rate = 0.001
def lr_schedule(epoch):
    return initial_learning_rate * (0.1 ** (epoch // 10))

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lr_schedule)

# Define the rest of your callbacks
my_callbacks = [
    ModelCheckpoint(filepath='cnnlstm.h5', verbose=1, save_best_only=True, monitor='val_accuracy', mode='max'),
    early_stopping,
    lr_scheduler
]
model = Sequential()

# Add Convolutional and MaxPooling Layers with L2 Regularization
model.add(Conv1D(64, 3, padding="same", input_shape=(Xtrain.shape[1], 1), activation='relu', kernel_regularizer=l2(0.01)))
model.add(Conv1D(64, 3, padding="same", activation='relu', kernel_regularizer=l2(0.01)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, 3, padding="same", activation='relu', kernel_regularizer=l2(0.001)))
model.add(Conv1D(128, 3, padding="same", activation='relu', kernel_regularizer=l2(0.001)))
model.add(MaxPooling1D(pool_size=2))

# Add Batch Normalization
model.add(BatchNormalization())

# Add LSTM layer with L2 Regularization
model.add(LSTM(units=100, return_sequences=False, dropout=0.1, kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))  # Add dropout to reduce overfitting

# Add Dense layer with L2 Regularization
model.add(Dense(units=2, activation='softmax', kernel_regularizer=l2(0.01)))  

# Compile the model with a custom learning rate schedule
opt = Adam(learning_rate=initial_learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 50, 64)            256
#
#  conv1d_9 (Conv1D)           (None, 50, 64)            12352
#
#  max_pooling1d_4 (MaxPoolin  (None, 25, 64)            0
#  g1D)
#
#  conv1d_10 (Conv1D)          (None, 25, 128)           24704
#
#  conv1d_11 (Conv1D)          (None, 25, 128)           49280
#
#  max_pooling1d_5 (MaxPoolin  (None, 12, 128)           0
#  g1D)
#
#  batch_normalization_2 (Bat  (None, 12, 128)           512
#  chNormalization)
#
#  lstm_2 (LSTM)               (None, 100)               91600
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 178805 (698.46 KB)
# Trainable params: 178549 (697.46 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
history = model.fit(Xtrain, y_train, epochs=50, batch_size=64, validation_data=(Xtest, y_test), callbacks=my_callbacks)
# Out:
# Epoch 1/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.4111 - accuracy: 0.9243
# Epoch 1: val_accuracy improved from -inf to 0.83333, saving model to cnnlstm.h5
# 750/750 [==============================] - 17s 18ms/step - loss: 0.4108 - accuracy: 0.9243 - val_loss: 0.7983 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 2/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1882 - accuracy: 0.9435
# Epoch 2: val_accuracy improved from 0.83333 to 0.90317, saving model to cnnlstm.h5
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1884 - accuracy: 0.9435 - val_loss: 0.3956 - val_accuracy: 0.9032 - lr: 0.0010
# Epoch 3/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9458
# Epoch 3: val_accuracy did not improve from 0.90317
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1735 - accuracy: 0.9457 - val_loss: 0.2341 - val_accuracy: 0.8833 - lr: 0.0010
# Epoch 4/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1579 - accuracy: 0.9485
# Epoch 4: val_accuracy did not improve from 0.90317
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1579 - accuracy: 0.9485 - val_loss: 1.7608 - val_accuracy: 0.4126 - lr: 0.0010
# Epoch 5/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1514 - accuracy: 0.9503
# Epoch 5: val_accuracy did not improve from 0.90317
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1516 - accuracy: 0.9503 - val_loss: 0.3433 - val_accuracy: 0.9011 - lr: 0.0010
# Epoch 6/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1496 - accuracy: 0.9499
# Epoch 6: val_accuracy improved from 0.90317 to 0.94950, saving model to cnnlstm.h5
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1498 - accuracy: 0.9499 - val_loss: 0.1468 - val_accuracy: 0.9495 - lr: 0.0010
# Epoch 7/50
# 746/750 [============================>.] - ETA: 0s - loss: 0.1436 - accuracy: 0.9526
# Epoch 7: val_accuracy did not improve from 0.94950
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1435 - accuracy: 0.9526 - val_loss: 0.4936 - val_accuracy: 0.8918 - lr: 0.0010
# Epoch 8/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9518
# Epoch 8: val_accuracy did not improve from 0.94950
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1408 - accuracy: 0.9518 - val_loss: 0.5716 - val_accuracy: 0.5311 - lr: 0.0010
# Epoch 9/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1371 - accuracy: 0.9529
# Epoch 9: val_accuracy did not improve from 0.94950
# 750/750 [==============================] - 12s 15ms/step - loss: 0.1371 - accuracy: 0.9529 - val_loss: 0.8245 - val_accuracy: 0.3334 - lr: 0.0010
# Epoch 10/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1378 - accuracy: 0.9531
# Epoch 10: val_accuracy did not improve from 0.94950
# 750/750 [==============================] - 11s 15ms/step - loss: 0.1377 - accuracy: 0.9531 - val_loss: 0.9271 - val_accuracy: 0.2477 - lr: 0.0010
# Epoch 11/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1232 - accuracy: 0.9570
# Epoch 11: val_accuracy improved from 0.94950 to 0.95500, saving model to cnnlstm.h5
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1231 - accuracy: 0.9570 - val_loss: 0.1370 - val_accuracy: 0.9550 - lr: 1.0000e-04
# Epoch 12/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9603
# Epoch 12: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1177 - accuracy: 0.9603 - val_loss: 0.2510 - val_accuracy: 0.9271 - lr: 1.0000e-04
# Epoch 13/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9599
# Epoch 13: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 13s 18ms/step - loss: 0.1170 - accuracy: 0.9599 - val_loss: 0.2338 - val_accuracy: 0.9276 - lr: 1.0000e-04
# Epoch 14/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9607
# Epoch 14: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1153 - accuracy: 0.9607 - val_loss: 0.1290 - val_accuracy: 0.9542 - lr: 1.0000e-04
# Epoch 15/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9593
# Epoch 15: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1147 - accuracy: 0.9594 - val_loss: 0.1689 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 16/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1133 - accuracy: 0.9615
# Epoch 16: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1132 - accuracy: 0.9616 - val_loss: 0.1840 - val_accuracy: 0.9264 - lr: 1.0000e-04
# Epoch 17/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1130 - accuracy: 0.9605
# Epoch 17: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1130 - accuracy: 0.9605 - val_loss: 0.1966 - val_accuracy: 0.9182 - lr: 1.0000e-04
# Epoch 18/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1118 - accuracy: 0.9610
# Epoch 18: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1118 - accuracy: 0.9609 - val_loss: 0.2002 - val_accuracy: 0.9172 - lr: 1.0000e-04
# Epoch 19/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9614
# Epoch 19: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1114 - accuracy: 0.9615 - val_loss: 0.5934 - val_accuracy: 0.4648 - lr: 1.0000e-04
# Epoch 20/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1102 - accuracy: 0.9611
# Epoch 20: val_accuracy did not improve from 0.95500
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1102 - accuracy: 0.9611 - val_loss: 0.6649 - val_accuracy: 0.4077 - lr: 1.0000e-04
# Epoch 21/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1082 - accuracy: 0.9619
# Epoch 21: val_accuracy improved from 0.95500 to 0.95675, saving model to cnnlstm.h5
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1082 - accuracy: 0.9619 - val_loss: 0.1162 - val_accuracy: 0.9567 - lr: 1.0000e-05
# Epoch 22/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9622
# Epoch 22: val_accuracy improved from 0.95675 to 0.96125, saving model to cnnlstm.h5
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1080 - accuracy: 0.9621 - val_loss: 0.1104 - val_accuracy: 0.9613 - lr: 1.0000e-05
# Epoch 23/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9624
# Epoch 23: val_accuracy did not improve from 0.96125
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1080 - accuracy: 0.9625 - val_loss: 0.1121 - val_accuracy: 0.9603 - lr: 1.0000e-05
# Epoch 24/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1077 - accuracy: 0.9621
# Epoch 24: val_accuracy did not improve from 0.96125
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1079 - accuracy: 0.9621 - val_loss: 0.1151 - val_accuracy: 0.9571 - lr: 1.0000e-05
# Epoch 25/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9622
# Epoch 25: val_accuracy did not improve from 0.96125
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1080 - accuracy: 0.9622 - val_loss: 0.1101 - val_accuracy: 0.9608 - lr: 1.0000e-05
# Epoch 26/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9617
# Epoch 26: val_accuracy did not improve from 0.96125
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1077 - accuracy: 0.9617 - val_loss: 0.1168 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Epoch 27/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9615
# Epoch 27: val_accuracy did not improve from 0.96125
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1074 - accuracy: 0.9616 - val_loss: 0.1351 - val_accuracy: 0.9410 - lr: 1.0000e-05
# Epoch 28/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1079 - accuracy: 0.9621
# Epoch 28: val_accuracy improved from 0.96125 to 0.96150, saving model to cnnlstm.h5
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1081 - accuracy: 0.9621 - val_loss: 0.1066 - val_accuracy: 0.9615 - lr: 1.0000e-05
# Epoch 29/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9615
# Epoch 29: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1076 - accuracy: 0.9615 - val_loss: 0.1197 - val_accuracy: 0.9479 - lr: 1.0000e-05
# Epoch 30/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9627
# Epoch 30: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1069 - accuracy: 0.9627 - val_loss: 0.1082 - val_accuracy: 0.9609 - lr: 1.0000e-05
# Epoch 31/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.9627
# Epoch 31: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1067 - accuracy: 0.9627 - val_loss: 0.1050 - val_accuracy: 0.9611 - lr: 1.0000e-06
# Epoch 32/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9623
# Epoch 32: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1071 - accuracy: 0.9623 - val_loss: 0.1050 - val_accuracy: 0.9612 - lr: 1.0000e-06
# Epoch 33/50
# 746/750 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9619
# Epoch 33: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1059 - accuracy: 0.9619 - val_loss: 0.1049 - val_accuracy: 0.9612 - lr: 1.0000e-06
# Epoch 34/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1068 - accuracy: 0.9628
# Epoch 34: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1069 - accuracy: 0.9626 - val_loss: 0.1047 - val_accuracy: 0.9610 - lr: 1.0000e-06
# Epoch 35/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9620
# Epoch 35: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1073 - accuracy: 0.9621 - val_loss: 0.1048 - val_accuracy: 0.9611 - lr: 1.0000e-06
# Epoch 36/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9629
# Epoch 36: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1068 - accuracy: 0.9629 - val_loss: 0.1049 - val_accuracy: 0.9613 - lr: 1.0000e-06
# Epoch 37/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9627
# Epoch 37: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1073 - accuracy: 0.9628 - val_loss: 0.1048 - val_accuracy: 0.9613 - lr: 1.0000e-06
# Epoch 38/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9619
# Epoch 38: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1075 - accuracy: 0.9619 - val_loss: 0.1048 - val_accuracy: 0.9613 - lr: 1.0000e-06
# Epoch 39/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.9627
# Epoch 39: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1070 - accuracy: 0.9628 - val_loss: 0.1048 - val_accuracy: 0.9613 - lr: 1.0000e-06
# Epoch 40/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1073 - accuracy: 0.9626
# Epoch 40: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1073 - accuracy: 0.9625 - val_loss: 0.1047 - val_accuracy: 0.9613 - lr: 1.0000e-06
# Epoch 41/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9625
# Epoch 41: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1064 - accuracy: 0.9625 - val_loss: 0.1046 - val_accuracy: 0.9612 - lr: 1.0000e-07
# Epoch 42/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9620
# Epoch 42: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1069 - accuracy: 0.9621 - val_loss: 0.1046 - val_accuracy: 0.9613 - lr: 1.0000e-07
# Epoch 43/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1068 - accuracy: 0.9623
# Epoch 43: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1067 - accuracy: 0.9623 - val_loss: 0.1046 - val_accuracy: 0.9612 - lr: 1.0000e-07
# Epoch 44/50
# 747/750 [============================>.] - ETA: 0s - loss: 0.1069 - accuracy: 0.9625
# Epoch 44: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1069 - accuracy: 0.9625 - val_loss: 0.1046 - val_accuracy: 0.9612 - lr: 1.0000e-07
# Epoch 45/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9620
# Epoch 45: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1073 - accuracy: 0.9620 - val_loss: 0.1046 - val_accuracy: 0.9611 - lr: 1.0000e-07
# Epoch 46/50
# 748/750 [============================>.] - ETA: 0s - loss: 0.1069 - accuracy: 0.9623
# Epoch 46: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1071 - accuracy: 0.9622 - val_loss: 0.1046 - val_accuracy: 0.9612 - lr: 1.0000e-07
# Epoch 47/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9620
# Epoch 47: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1074 - accuracy: 0.9620 - val_loss: 0.1046 - val_accuracy: 0.9612 - lr: 1.0000e-07
# Epoch 48/50
# 749/750 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9628
# Epoch 48: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1066 - accuracy: 0.9628 - val_loss: 0.1046 - val_accuracy: 0.9611 - lr: 1.0000e-07
# Epoch 49/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9626
# Epoch 49: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 17ms/step - loss: 0.1068 - accuracy: 0.9626 - val_loss: 0.1046 - val_accuracy: 0.9612 - lr: 1.0000e-07
# Epoch 50/50
# 750/750 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9623
# Epoch 50: val_accuracy did not improve from 0.96150
# 750/750 [==============================] - 12s 16ms/step - loss: 0.1070 - accuracy: 0.9623 - val_loss: 0.1046 - val_accuracy: 0.9612 - lr: 1.0000e-07

# %%
model.save('model.h5')

# %%
history_dict = history.history

val_accc = history_dict.get('val_accuracy') 

train_accc = history_dict.get('accuracy') 
val_losss = history_dict.get('val_loss')   
losss = history_dict.get('loss')          

threshold = 0.70
history_epochs = []
loss = []
val_loss = []
accuracy = []
val_accuracy = []

for i, acc in enumerate(val_accc):
    if acc >= threshold:
        loss.append(losss[i])
        val_loss.append(val_losss[i])
        accuracy.append(train_accc[i])
        val_accuracy.append(acc)

# %%
import matplotlib.pyplot as plt



# Plot Training and Validation Loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)  # Subplot for loss
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Training and Validation Accuracy
plt.subplot(1, 2, 2)  # Subplot for accuracy
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
